# %%
print("Hello World!")
print(10)
# Out:
# Hello World!
# 10

# %%
palavra = "Hello guys!"
print(palavra)
# Out:
# Hello guys!

# %% [markdown]
# Teste de anotação!!!

# %%
num1 = 10
num2 = 16

def soma():
  return print(num1 + num2)

soma()
# Out:
# 26

# %%
print('César', 42)
# Out:
# César 42

# %% [markdown]
# Exercícios

# %%
print('Escola de Dados da Alura!')
# Out:
# Escola de Dados da Alura!

# %%
nome = 'César'
sobrenome = 'Guilherme'
print(f'Nome: {nome}\nSobrenome: {sobrenome}')
# Out:
# Nome: César
# Sobrenome: Guilherme

# %%
print('C\nE\nS\nA\nR')
# Out:
# C
# E
# S
# A
# R

# %%
print(2, 'de maio de', 1983)
# Out:
# 2 de maio de 1983

# %%
print('Ano atual:', 2025)
# Out:
# Ano atual: 2025
