# %%
print("Hello World!")
# Out:
# Hello World!

# %%
palavra = "Hello guys!"
print(palavra)
# Out:
# Hello guys!

# %% [markdown]
# Teste de anotação!!!

# %%
num1 = 10
num2 = 16

def soma():
  return print(num1 + num2)

soma()
# Out:
# 26
