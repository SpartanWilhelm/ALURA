# %%
notas = [8.5, 9.0, 6.0, 10.0]

# %%
def media(lista):
    calculo = sum(lista) / len(lista)
    return calculo

# %%
resultado = media(notas)

# %%
resultado
# Out:
# 8.375

# %%
notas = [6.0, 7.0, 9.0, 5.0]

# %%
def boletim(lista):
    media = sum(lista) / len(lista)

    if media >= 6:
        situacao = "Aprovado(a)"
    else:
        situacao = "Reprovado(a)"
        
    return (f'A média é {media} e o(a) aluno(a) está {situacao}')

# %%
boletim(notas)
# Out:
# 'A média é 6.75 e o(a) aluno(a) está Aprovado(a)'

# %%
nota = 5

nota_atualizada = lambda x : x + 0.5

# %%
nota_atualizada(nota)
# Out:
# 5.5

# %%
N1 = 6
N2 = 3
N3 = 5

media_ponderavel = lambda x, y, z : (x*3 + y*2 + z*5)/10

media_estudante = media_ponderavel(N1, N2, N3)
media_estudante
# Out:
# 4.9

# %%
print(f'O(a) estudante atingiu uma média ponderavel de {media_estudante}')
# Out:
# O(a) estudante atingiu uma média ponderavel de 4.9

# %%
notas = [6.0,7.0,9.0,5.5,8.0]
qualitativo = 0.5

# %%
notas_atualizadas = lambda x: x+qualitativo

notas_atualizadas(notas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 notas_atualizadas = lambda x: x+qualitativo
# ----> 3 notas_atualizadas(notas)
#
# Cell In[14], line 1, in <lambda>(x)
# ----> 1 notas_atualizadas = lambda x: x+qualitativo
#       3 notas_atualizadas(notas)
#
# TypeError: can only concatenate list (not "float") to list

# %%
notas_atualizadas = map(lambda x: x+qualitativo, notas)
notas_atualizadas

# %%
notas_atualizadas = list(notas_atualizadas)

# %%
notas_atualizadas
# Out:
# [6.5, 7.5, 9.5, 6.0, 8.5]
